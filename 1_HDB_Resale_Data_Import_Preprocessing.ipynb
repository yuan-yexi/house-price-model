# %%
# import essential data handling libraries
import pandas as pd
import numpy as np
import json
import requests
from geopy.distance import geodesic
import time
from datetime import datetime

# %%
def get_hdb_resale_data():
    # importing our data set from data.gov.sg
    query_string='https://data.gov.sg/api/action/datastore_search?resource_id=42ff9cfe-abe5-4b54-beda-c88f9bb438ee&limit=1000000'
    resp = requests.get(query_string)

    #Convert JSON into Python Object 
    data = json.loads(resp.content)

    # Checking the length of dataframeenrich_geo_coordinate
    len(data['result']['records']) 

    # Store our dictionart records into hdb_price_dict_records
    hdb_price_dict_records = data['result']['records']

    # Next we need to feed our JSON data into dataframe. 
    # We will access the 'records' key:value pairs of the python dictionary. 
    # We will then map the list into a dataframe.
    town = []
    flat_type = []
    flat_model = []
    floor_area_sqm = []
    street_name = []
    resale_price = []
    month = []
    remaining_lease = []
    lease_commence_date = []
    storey_range = []
    _id = []
    block = []

    for i in range(0, len(hdb_price_dict_records)):
        town.append(hdb_price_dict_records[i]['town'])
        flat_type.append(hdb_price_dict_records[i]['flat_type'])
        flat_model.append(hdb_price_dict_records[i]['flat_model'])
        floor_area_sqm.append(hdb_price_dict_records[i]['floor_area_sqm'])
        street_name.append(hdb_price_dict_records[i]['street_name'])
        resale_price.append(hdb_price_dict_records[i]['resale_price'])
        month.append(hdb_price_dict_records[i]['month'])
        remaining_lease.append(hdb_price_dict_records[i]['remaining_lease'])
        lease_commence_date.append(hdb_price_dict_records[i]['lease_commence_date'])
        storey_range.append(hdb_price_dict_records[i]['storey_range'])
        _id.append(hdb_price_dict_records[i]['_id'])
        block.append(hdb_price_dict_records[i]['block'])
        
    df = pd.DataFrame({
        'town': town,
        'flat_type': flat_type,
        'flat_model': flat_model,
        'floor_area_sqm': floor_area_sqm,
        'street_name': street_name,
        'resale_price': resale_price,
        'month': month,
        'remaining_lease': remaining_lease,
        'lease_commence_date': lease_commence_date,
        'storey_range': storey_range,
        '_id': _id,
        'block': block
    })

    df['address'] = df['block'] + ' ' + df['street_name']

    return df

# %%
df_hdb_price = get_hdb_resale_data()

# %%
# Let's examine our dataframe
df_hdb_price.head()
# Out:
#          town flat_type      flat_model floor_area_sqm        street_name  \
# 0  ANG MO KIO    2 ROOM        Improved             44  ANG MO KIO AVE 10
# 1  ANG MO KIO    3 ROOM  New Generation             67   ANG MO KIO AVE 4
# 2  ANG MO KIO    3 ROOM  New Generation             67   ANG MO KIO AVE 5
# 3  ANG MO KIO    3 ROOM  New Generation             68  ANG MO KIO AVE 10
# 4  ANG MO KIO    3 ROOM  New Generation             67   ANG MO KIO AVE 5
#
#   resale_price    month     remaining_lease lease_commence_date storey_range  \
# 0       232000  2017-01  61 years 04 months                1979     10 TO 12
# 1       250000  2017-01  60 years 07 months                1978     01 TO 03
# 2       262000  2017-01  62 years 05 months                1980     01 TO 03
# 3       265000  2017-01   62 years 01 month                1980     04 TO 06
# 4       265000  2017-01  62 years 05 months                1980     01 TO 03
#
#    _id block                address
# 0    1   406  406 ANG MO KIO AVE 10
# 1    2   108   108 ANG MO KIO AVE 4
# 2    3   602   602 ANG MO KIO AVE 5
# 3    4   465  465 ANG MO KIO AVE 10
# 4    5   601   601 ANG MO KIO AVE 5

# %%
df_hdb_price.shape
# Out:
# (70104, 13)

# %%
# Create a function that creates data frames of key locations
def get_geo_coordinates(df):
    list_of_location = df.iloc[:,1].tolist()
    # Obtaining Mall Coordinates in Singapore
    address_name = []
    address_roadname = []
    address_lat = []
    address_long = []

    for i in range(0, len(list_of_location)):
        query_address = list_of_location[i]
        query_string = 'https://developers.onemap.sg/commonapi/search?searchVal='+str(query_address)+'&returnGeom=Y&getAddrDetails=Y'
        resp = requests.get(query_string)
        data = json.loads(resp.content)
        
        if data['found'] != 0:
            address_name.append(query_address)
            address_roadname.append(data["results"][0]["ROAD_NAME"])
            address_lat.append(data["results"][0]["LATITUDE"])
            address_long.append(data["results"][0]["LONGITUDE"])

            print (str(query_address)+ " ,Lat: " +data['results'][0]['LATITUDE'] + " Long: " + data['results'][0]['LONGITUDE'])

        else:
            print ("No Results")
            
    # Store this information in a dataframe
    return pd.DataFrame({
                'address': address_name,
                'roadName': address_roadname,
                'latitude': address_lat,
                'longitude': address_long
            })

# %%
# import csv of locations of interests
df_shopping_malls_list = pd.read_csv("./shopping_malls.csv")
df_mrt_stations_list = pd.read_csv("./data_sets/mrt_stations.csv")
df_govt_funded_schools_list = pd.read_csv("./data_sets/govt_funded_schools.csv")
df_govt_aided_schools_list = pd.read_csv("./data_sets/govt_aided_schools.csv")
df_sap_schools_list = pd.read_csv("./data_sets/sap_schools.csv")

df_mall = get_geo_coordinates(df_shopping_malls_list)
df_mrt = get_geo_coordinates(df_mrt_stations_list)
df_govt_funded_schools = get_geo_coordinates(df_govt_funded_schools_list)
df_govt_aided_schools = get_geo_coordinates(df_govt_aided_schools_list)
df_sap_schools = get_geo_coordinates(df_sap_schools_list)

df_mall.to_csv('./data_sets/df_mall.csv', index = False)
df_mrt.to_csv('./data_sets/df_mrt.csv', index = False)
df_govt_funded_schools.to_csv('./data_sets/df_govt_funded_schools.csv', index = False)
df_govt_aided_schools.to_csv('./data_sets/df_govt_aided_schools.csv', index = False)
df_sap_schools.to_csv('./data_sets/df_sap_schools.csv', index = False)
# Out:
# 100 AM ,Lat: 1.2745882179999999 Long: 103.84347070000001
# 313@Somerset ,Lat: 1.301385102 Long: 103.8376844
# Aperia ,Lat: 1.30974242 Long: 103.8641016
# Balestier Hill Shopping Centre ,Lat: 1.326124169 Long: 103.8437095
# Bugis Cube ,Lat: 1.298195005 Long: 103.85565550000001
# Bugis Junction ,Lat: 1.300117893 Long: 103.8561916
# Bugis+ ,Lat: 1.300779548 Long: 103.85632779999999
# Capitol Piazza ,Lat: 1.293063359 Long: 103.85129350000001
# Cathay Cineleisure Orchard ,Lat: 1.301497434 Long: 103.8364448
# City Gate ,Lat: 1.302347543 Long: 103.86225999999999
# City Square Mall ,Lat: 1.31147745 Long: 103.8567808
# CityLink Mall ,Lat: 1.292378607 Long: 103.854663
# No Results
# Duo ,Lat: 1.299216621 Long: 103.8579968
# Far East Plaza ,Lat: 1.3073111259999999 Long: 103.83394
# Funan ,Lat: 1.2912440059999999 Long: 103.8499848
# Great World City ,Lat: 1.293154929 Long: 103.831928
# HDB Hub ,Lat: 1.33218812 Long: 103.8470778
# No Results
# ION Orchard ,Lat: 1.3040425340000001 Long: 103.83188829999999
# Junction 8 ,Lat: 1.3502394309999999 Long: 103.8484776
# No Results
# Liang Court ,Lat: 1.290658604 Long: 103.84454720000001
# Liat Towers ,Lat: 1.30510759 Long: 103.83072790000001
# Lucky Plaza ,Lat: 1.30446379 Long: 103.83400520000001
# Marina Bay Financial Centre Tower 3 ,Lat: 1.279124938 Long: 103.85445759999999
# Marina Bay Link Mall ,Lat: 1.2804679429999999 Long: 103.85347009999998
# Marina Bay Sands ,Lat: 1.283994101 Long: 103.85945059999999
# Marina One ,Lat: 1.27704169 Long: 103.85340190000001
# Marina Square ,Lat: 1.2910398029999999 Long: 103.8576235
# Midpoint Orchard ,Lat: 1.301783782 Long: 103.8386606
# Millenia Walk ,Lat: 1.292046053 Long: 103.8599002
# No Results
# Ngee Ann City ,Lat: 1.302424172 Long: 103.8346761
# Orchard Central ,Lat: 1.300723504 Long: 103.83969240000002
# Orchard Gateway ,Lat: 1.300443253 Long: 103.8394428
# Orchard Plaza ,Lat: 1.30126533 Long: 103.84115179999999
# Orchard Shopping Centre ,Lat: 1.301484998 Long: 103.83788829999999
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-2a998b8aadfc> in <module>
#       6 df_sap_schools_list = pd.read_csv("./data_sets/sap_schools.csv")
#       7
# ----> 8 df_mall = get_geo_coordinates(df_shopping_malls_list)
#       9 df_mrt = get_geo_coordinates(df_mrt_stations_list)
#      10 df_govt_funded_schools = get_geo_coordinates(df_govt_funded_schools_list)
#
# <ipython-input-6-45eff10c7953> in get_geo_coordinates(df)
#      11         query_address = list_of_location[i]
#      12         query_string = 'https://developers.onemap.sg/commonapi/search?searchVal='+str(query_address)+'&returnGeom=Y&getAddrDetails=Y'
# ---> 13         resp = requests.get(query_string)
#      14         data = json.loads(resp.content)
#      15
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     374         # Trigger any extra validation we need to do.
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#     378             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     992         # Force connect early to allow us to validate the connection.
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#     996         if not conn.is_verified:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     358             ca_cert_dir=self.ca_cert_dir,
#     359             server_hostname=server_hostname,
# --> 360             ssl_context=context,
#     361         )
#     362
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     368     ) or IS_SECURETRANSPORT:
#     369         if HAS_SNI and server_hostname is not None:
# --> 370             return context.wrap_socket(sock, server_hostname=server_hostname)
#     371
#     372         warnings.warn(
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     483         while True:
#     484             try:
# --> 485                 cnx.do_handshake()
#     486             except OpenSSL.SSL.WantReadError:
#     487                 if not util.wait_for_read(sock, sock.gettimeout()):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1931         :return: None.
#    1932         """
# -> 1933         result = _lib.SSL_do_handshake(self._ssl)
#    1934         self._raise_ssl_error(self._ssl, result)
#    1935
#
# KeyboardInterrupt:

# %%
df_mall.to_csv('./data_sets/df_mall.csv', index = False)
df_mrt.to_csv('./data_sets/df_mrt.csv', index = False)
df_govt_funded_schools.to_csv('./data_sets/df_govt_funded_schools.csv', index = False)
df_govt_aided_schools.to_csv('./data_sets/df_govt_aided_schools.csv', index = False)
df_sap_schools.to_csv('./data_sets/df_sap_schools.csv', index = False)

# %%
def enrich_lat_lg_unique(df):
    # Create address column
    if 'address' not in df.columns:
        df['address'] = df['block'] + " " + df['street_name']
    
    # Dedup Address List
    df_dedup = df.drop_duplicates(subset='address', keep='first')
    df_dedup['address'] = df_dedup['address'].str.replace("ST. GEORGE'S", "SAINT GEORGE'S")

    # Next let's grab the unique addresses and create a list 
    address_list = df_dedup['address'].tolist()

    no_items = len(address_list)
    latitude = []
    longitude = []
    blk_no = []
    road_name = []
    postal_code = []
    address = []
    count = 0
    print(f"{no_items} rows of addresses to enrich")
    for row in range(len(address_list)):
        #formulate query string  
        query_address = address_list[row]
        query_string='https://developers.onemap.sg/commonapi/search?searchVal='+str(query_address)+'&returnGeom=Y&getAddrDetails=Y'
        resp = requests.get(query_string)

        #Convert JSON into Python Object 
        data_geo_location=json.loads(resp.content)

        if data_geo_location['found'] != 0:
            latitude.append(data_geo_location['results'][0]['LATITUDE'])
            longitude.append(data_geo_location['results'][0]['LONGITUDE'])
            blk_no.append(data_geo_location['results'][0]['BLK_NO'])
            road_name.append(data_geo_location['results'][0]['ROAD_NAME'])
            postal_code.append(data_geo_location['results'][0]['POSTAL'])
            address.append(query_address)
            print (str(round((row / no_items)*100, 2)) + "% " + "Completed: " + str(query_address) + " ,Lat: " + data_geo_location['results'][0]['LATITUDE'] + " Long: " + data_geo_location['results'][0]['LONGITUDE'])
        else:
            latitude.append(None)
            longitude.append(None)
            blk_no.append(None)
            road_name.append(None)
            postal_code.append(None)
            address.append(query_address)
            print (str(round((row / no_items)*100, 2)) + "%" + ": " + str(query_address) +  "No Results")

    # Fit into a dataframe
    return pd.DataFrame({
                'latitude': latitude,
                'longitude': longitude,
                'blk_no': blk_no,
                'road_name': road_name,
                'postal_code': postal_code,
                'address': address
            })

# %%
start_time = time.time()
df_enriched = enrich_lat_lg_unique(df_hdb_price)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 8712 rows of addresses to enrich
# 0.0% Completed: 406 ANG MO KIO AVE 10 ,Lat: 1.362004539 Long: 103.85387990000001
# 0.01% Completed: 108 ANG MO KIO AVE 4 ,Lat: 1.370966352 Long: 103.83820190000002
# 0.02% Completed: 602 ANG MO KIO AVE 5 ,Lat: 1.3809284309999998 Long: 103.8359538
# 0.03% Completed: 465 ANG MO KIO AVE 10 ,Lat: 1.3662010409999998 Long: 103.857201
# 0.05% Completed: 601 ANG MO KIO AVE 5 ,Lat: 1.381041355 Long: 103.8351317
# 0.06% Completed: 150 ANG MO KIO AVE 5 ,Lat: 1.376806785 Long: 103.84201800000001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-153315d7b7c1> in <module>
#       1 start_time = time.time()
# ----> 2 df_enriched = enrich_lat_lg_unique(df_hdb_price)
#       3 print("--- %s seconds ---" % (time.time() - start_time))
#
# <ipython-input-8-f61e3687716e> in enrich_lat_lg_unique(df)
#      24         query_address = address_list[row]
#      25         query_string='https://developers.onemap.sg/commonapi/search?searchVal='+str(query_address)+'&returnGeom=Y&getAddrDetails=Y'
# ---> 26         resp = requests.get(query_string)
#      27
#      28         #Convert JSON into Python Object
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     374         # Trigger any extra validation we need to do.
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#     378             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     992         # Force connect early to allow us to validate the connection.
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#     996         if not conn.is_verified:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     298     def connect(self):
#     299         # Add certificate verification
# --> 300         conn = self._new_conn()
#     301         hostname = self.host
#     302
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     155         try:
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#     159
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72             if source_address:
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#      76
#
# KeyboardInterrupt:

# %%
df_enriched.shape
# Out:
# (8712, 6)

# %%
def export_missing_values(df):
    if df['latitude'].isna().sum() != 0:
        df[df['latitude'].isna()].to_csv("./data_sets/missing_lat_lng"+datetime.today().strftime("%Y-%m-%d")+".csv", index = False)
        df_missing_lat_lng.dropna().to_csv("./data_sets/unique_address_lat_lng_with_missing"+datetime.today().strftime("%Y-%m-%d")+".csv", index = False)
    else:
        df.to_csv("./data_sets/unique_address_lat_lng_no_missing"+datetime.today().strftime("%Y-%m-%d")+".csv", index = False)

# %%
export_missing_values(df_enriched)

# %%
df_enriched.dropna(inplace=True)
df_enriched.isna().sum()
# Out:
# latitude       0
# longitude      0
# blk_no         0
# road_name      0
# postal_code    0
# address        0
# dtype: int64

# %%
def get_lat_lng(df):
    list_of_lat = df['latitude']
    list_of_lng = df['longitude']
    list_of_lat_lng = []
    for lat, lng in zip(list_of_lat, list_of_lng):
        list_of_lat_lng.append((lat,lng))
    return list_of_lat_lng

# %%
hdb_lat_lng = get_lat_lng(df_enriched)
mall_lat_lng = get_lat_lng(df_mall)
mrt_lat_lng = get_lat_lng(df_mrt)
govt_aided_lat_lng = get_lat_lng(df_govt_aided_schools)
govt_funded_lat_lng = get_lat_lng(df_govt_funded_schools)
sap_lat_lng = get_lat_lng(df_sap_schools)

# %%
def get_nearest_dist_m(lst_origin, lst_destination):
    list_of_distances = []
    shortest_distance = []

    for origin in lst_origin:
        for destination in range(0, len(lst_destination)):
          list_of_distances.append(geodesic(origin, lst_destination[destination]).meters)
        shortest = min(list_of_distances)
        print(f'Shortest distance is {shortest} meters')
        shortest_distance.append(shortest)
        list_of_distances.clear()
    return shortest_distance

# %%
start_time = time.time()
nearest_mrt_dist = get_nearest_dist_m(hdb_lat_lng, mrt_lat_lng)
nearest_mall_dist = get_nearest_dist_m(hdb_lat_lng, mall_lat_lng)
nearest_govt_aided_dist = get_nearest_dist_m(hdb_lat_lng, govt_aided_lat_lng)
nearest_govt_funded_dist = get_nearest_dist_m(hdb_lat_lng, govt_funded_lat_lng)
nearest_sap_dist = get_nearest_dist_m(hdb_lat_lng, sap_lat_lng)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ce is 8868.898902867026 meters
# Shortest distance is 9106.762193145029 meters
# Shortest distance is 8979.610395977472 meters
# Shortest distance is 8085.723291567563 meters
# Shortest distance is 9238.33223063257 meters
# Shortest distance is 5682.6973577556755 meters
# Shortest distance is 6555.378212911782 meters
# Shortest distance is 5505.920591157376 meters
# Shortest distance is 6500.848159000282 meters
# Shortest distance is 4760.0393139766875 meters
# Shortest distance is 6545.332098779419 meters
# Shortest distance is 6547.645991209826 meters
# Shortest distance is 6624.718213951538 meters
# Shortest distance is 1852.9097101927698 meters
# Shortest distance is 1656.2847649256414 meters
# Shortest distance is 343.98608706142966 meters
# Shortest distance is 1139.1160079656959 meters
# Shortest distance is 4301.299195652244 meters
# Shortest distance is 3560.855823572457 meters
# Shortest distance is 3921.4882960575587 meters
# Shortest distance is 5677.625644203869 meters
# Shortest distance is 5571.208246159869 meters
# Shortest distance is 5680.206393926434 meters
# Shortest distance is 5591.134022292626 meters
# Shortest distance is 1165.6231476956477 meters
# Shortest distance is 1642.121602054221 meters
# Shortest distance is 1519.8417258643885 meters
# Shortest distance is 1493.092967404076 meters
# Shortest distance is 3029.743653513132 meters
# Shortest distance is 3550.759736483349 meters
# Shortest distance is 5337.645064279763 meters
# Shortest distance is 8573.882742825568 meters
# Shortest distance is 4947.027056866855 meters
# Shortest distance is 4856.223228714519 meters
# Shortest distance is 8610.86377807395 meters
# Shortest distance is 8469.5058301367 meters
# Shortest distance is 2153.113154320339 meters
# Shortest distance is 3173.3392080457083 meters
# Shortest distance is 3043.6072163953995 meters
# Shortest distance is 3146.8050366234647 meters
# Shortest distance is 3131.206125784167 meters
# Shortest distance is 3245.6620383888735 meters
# Shortest distance is 3088.774558455483 meters
# Shortest distance is 2153.474607974093 meters
# Shortest distance is 462.8225582677403 meters
# Shortest distance is 478.8025404946856 meters
# Shortest distance is 766.351099347145 meters
# Shortest distance is 8981.008457833817 meters
# Shortest distance is 8795.936982172714 meters
# Shortest distance is 8828.49748602229 meters
# Shortest distance is 5720.453506964161 meters
# Shortest distance is 5346.242878440994 meters
# Shortest distance is 5314.369683823467 meters
# Shortest distance is 5590.377356871291 meters
# Shortest distance is 6560.625553931892 meters
# Shortest distance is 6624.275561124342 meters
# Shortest distance is 6675.279051460972 meters
# Shortest distance is 6427.2547752149385 meters
# Shortest distance is 1267.0102821409773 meters
# Shortest distance is 1080.9848436416705 meters
# Shortest distance is 759.2403135571318 meters
# Shortest distance is 5504.532526554137 meters
# Shortest distance is 5623.058096648532 meters
# Shortest distance is 167.5620821470928 meters
# Shortest distance is 508.5308721876818 meters
# Shortest distance is 1487.4608527957066 meters
# Shortest distance is 1574.3266346037212 meters
# Shortest distance is 3089.629412699609 meters
# Shortest distance is 1338.1395227434764 meters
# Shortest distance is 2952.946186349083 meters
# Shortest distance is 5949.368174456309 meters
# Shortest distance is 5865.815022876119 meters
# Shortest distance is 5907.136877170231 meters
# Shortest distance is 597.4702157217234 meters
# Shortest distance is 2518.844952854333 meters
# Shortest distance is 3370.1819786320098 meters
# Shortest distance is 4363.223137327635 meters
# Shortest distance is 4954.875629110816 meters
# Shortest distance is 4930.791543936846 meters
# Shortest distance is 2095.788040404692 meters
# Shortest distance is 3531.4762103914063 meters
# Shortest distance is 3067.854108364145 meters
# Shortest distance is 3264.820719523544 meters
# Shortest distance is 3682.3913827891174 meters
# Shortest distance is 2155.1197776134936 meters
# Shortest distance is 2033.9010745159972 meters
# Shortest distance is 2992.280641564895 meters
# Shortest distance is 1394.9364916121854 meters
# Shortest distance is 1437.122081136387 meters
# Shortest distance is 833.5391776289928 meters
# Shortest distance is 1132.854768192382 meters
# Shortest distance is 427.6642820930402 meters
# Shortest distance is 416.38819216792456 meters
# Shortest distance is 1950.368515203989 meters
# Shortest distance is 2419.755779006065 meters
# Shortest distance is 975.0623532492708 meters
# Shortest distance is 1760.319563510803 meters
# Shortest distance is 699.8801070121893 meters
# Shortest distance is 8938.936052361307 meters
# Shortest distance is 8791.299408660443 meters
# Shortest distance is 5699.723131262239 meters
# Shortest distance is 6658.982737001077 meters
# Shortest distance is 5948.516679689867 meters
# Shortest distance is 6026.569818734674 meters
# Shortest distance is 5303.496587851299 meters
# Shortest distance is 5560.290488554482 meters
# Shortest distance is 5462.564032781504 meters
# Shortest distance is 6003.188816086328 meters
# Shortest distance is 6733.022332928229 meters
# Shortest distance is 6649.610591480662 meters
# Shortest distance is 5224.413639376113 meters
# Shortest distance is 5262.054874895719 meters
# Shortest distance is 1965.3995321134678 meters
# Shortest distance is 2368.5643313089176 meters
# Shortest distance is 3249.7885356363518 meters
# Shortest distance is 5562.407941573524 meters
# Shortest distance is 7564.07560881234 meters
# Shortest distance is 705.9938132143685 meters
# Shortest distance is 1661.3110151844708 meters
# Shortest distance is 4747.75854377134 meters
# Shortest distance is 2652.230052478851 meters
# Shortest distance is 7701.513299473525 meters
# Shortest distance is 4651.268864239638 meters
# Shortest distance is 4637.089600143856 meters
# Shortest distance is 691.2749346853652 meters
# Shortest distance is 1778.2218275524392 meters
# Shortest distance is 2589.7401586323635 meters
# Shortest distance is 4931.595777842695 meters
# Shortest distance is 3671.272219637333 meters
# Shortest distance is 3218.544295790818 meters
# Shortest distance is 2103.4736580630793 meters
# Shortest distance is 3532.1441861203944 meters
# Shortest distance is 3106.028944940575 meters
# Shortest distance is 3309.0331768979677 meters
# Shortest distance is 333.4671219323871 meters
# Shortest distance is 389.50293178067477 meters
# Shortest distance is 439.13605425674746 meters
# Shortest distance is 688.1312231376552 meters
# Shortest distance is 6358.194009467444 meters
# Shortest distance is 5195.917182577124 meters
# Shortest distance is 6629.786694441125 meters
# Shortest distance is 5856.8970811734425 meters
# Shortest distance is 439.67222253883875 meters
# Shortest distance is 4589.044395266929 meters
# Shortest distance is 5753.493195761496 meters
# Shortest distance is 7224.138520804979 meters
# Shortest distance is 7325.78223949655 meters
# Shortest distance is 1414.463007898535 meters
# Shortest distance is 1251.5689581013212 meters
# Shortest distance is 1029.7219946239827 meters
# Shortest distance is 2072.3590491233554 meters
# Shortest distance is 5946.767225197222 meters
# Shortest distance is 5503.813340705748 meters
# Shortest distance is 4716.032404098009 meters
# Shortest distance is 7767.241319829893 meters
# Shortest distance is 1526.978533764531 meters
# Shortest distance is 608.6543802150406 meters
# Shortest distance is 1674.4284373147693 meters
# Shortest distance is 1880.6670662910303 meters
# Shortest distance is 2005.201888952231 meters
# Shortest distance is 4993.2567397488365 meters
# Shortest distance is 4372.451438888188 meters
# Shortest distance is 2111.5434233940273 meters
# Shortest distance is 3587.522376397231 meters
# Shortest distance is 2106.1194756945106 meters
# Shortest distance is 3286.7183395435986 meters
# Shortest distance is 3367.198555959799 meters
# Shortest distance is 3617.738287292446 meters
# Shortest distance is 1875.7117887669358 meters
# Shortest distance is 2471.7638501675374 meters
# Shortest distance is 2066.751374671276 meters
# Shortest distance is 1881.0961328586718 meters
# Shortest distance is 553.0848220596897 meters
# Shortest distance is 3098.0169656319913 meters
# Shortest distance is 1721.441181749886 meters
# Shortest distance is 8446.381905855438 meters
# Shortest distance is 6711.892014985318 meters
# Shortest distance is 5274.494958810272 meters
# Shortest distance is 6751.8117288894755 meters
# Shortest distance is 6794.280001824265 meters
# Shortest distance is 6713.694901835963 meters
# Shortest distance is 1021.34532544029 meters
# Shortest distance is 847.5206700646606 meters
# Shortest distance is 3184.0845777142863 meters
# Shortest distance is 5253.373326452904 meters
# Shortest distance is 4569.397421170909 meters
# Shortest distance is 5641.542108843965 meters
# Shortest distance is 5501.452882308165 meters
# Shortest distance is 5717.890210002372 meters
# Shortest distance is 3985.7540054106644 meters
# Shortest distance is 7851.390087471695 meters
# Shortest distance is 7892.4634908546805 meters
# Shortest distance is 1829.207698142379 meters
# Shortest distance is 2824.484286437643 meters
# Shortest distance is 3145.3791407961926 meters
# Shortest distance is 4310.892680043392 meters
# Shortest distance is 1710.373025466916 meters
# Shortest distance is 3243.56911918301 meters
# Shortest distance is 3407.8338194100406 meters
# Shortest distance is 3335.558832152488 meters
# Shortest distance is 3567.7542096489583 meters
# Shortest distance is 3223.859342736348 meters
# Shortest distance is 407.5771269096372 meters
# Shortest distance is 521.1143517496043 meters
# Shortest distance is 527.9330361670737 meters
# Shortest distance is 365.4740471615882 meters
# Shortest distance is 515.7413271276747 meters
# Shortest distance is 728.6178523446727 meters
# Shortest distance is 1141.0986054724947 meters
# Shortest distance is 10662.89642189107 meters
# Shortest distance is 6587.421856693673 meters
# Shortest distance is 6313.154018801104 meters
# Shortest distance is 6680.595957170851 meters
# Shortest distance is 6644.752005830171 meters
# Shortest distance is 5235.2136123676455 meters
# Shortest distance is 1737.3052056345593 meters
# Shortest distance is 671.6995206486168 meters
# Shortest distance is 2451.3802814800524 meters
# Shortest distance is 4718.69483659621 meters
# Shortest distance is 4058.315851496446 meters
# Shortest distance is 5435.863790609252 meters
# Shortest distance is 5745.356613947714 meters
# Shortest distance is 5779.544366279159 meters
# Shortest distance is 6410.003321442656 meters
# Shortest distance is 5273.571283103157 meters
# Shortest distance is 6906.156729111593 meters
# Shortest distance is 1013.0598195026495 meters
# Shortest distance is 4238.577632369935 meters
# Shortest distance is 2474.548593307255 meters
# Shortest distance is 1692.7199051422306 meters
# Shortest distance is 1988.5506152464304 meters
# Shortest distance is 1810.3425836159875 meters
# Shortest distance is 1768.9414975259647 meters
# Shortest distance is 2051.0807195084085 meters
# Shortest distance is 505.3698480250958 meters
# Shortest distance is 2030.7696265661375 meters
# Shortest distance is 420.0048452791593 meters
# Shortest distance is 1046.6191071070066 meters
# Shortest distance is 9537.33150950636 meters
# Shortest distance is 8570.86299844077 meters
# Shortest distance is 6630.837496722005 meters
# Shortest distance is 6556.771546291296 meters
# Shortest distance is 5022.203882971956 meters
# Shortest distance is 5240.3820658578015 meters
# Shortest distance is 5100.845051940896 meters
# Shortest distance is 2296.8675831090163 meters
# Shortest distance is 2424.3396813957766 meters
# Shortest distance is 4603.458531632747 meters
# Shortest distance is 5458.294074886309 meters
# Shortest distance is 5741.3129724661685 meters
# Shortest distance is 5788.356206441334 meters
# Shortest distance is 5761.349339563442 meters
# Shortest distance is 5666.175626267073 meters
# Shortest distance is 5774.2856586904545 meters
# Shortest distance is 376.2799604686567 meters
# Shortest distance is 1656.5425387063535 meters
# Shortest distance is 857.6148039294889 meters
# Shortest distance is 1942.682152184562 meters
# Shortest distance is 1741.186449759466 meters
# Shortest distance is 1852.6521827959098 meters
# Shortest distance is 1965.636495639189 meters
# Shortest distance is 4110.447326652182 meters
# Shortest distance is 3421.71468903649 meters
# Shortest distance is 3560.034001810054 meters
# Shortest distance is 3444.1273502014215 meters
# Shortest distance is 3533.8616635875064 meters
# Shortest distance is 3319.5250806786316 meters
# Shortest distance is 3249.8751873942556 meters
# Shortest distance is 3484.427856457241 meters
# Shortest distance is 1204.2601364515046 meters
# Shortest distance is 2605.7269688379142 meters
# Shortest distance is 1267.105945645118 meters
# Shortest distance is 396.8493350979057 meters
# Shortest distance is 566.8204875984429 meters
# Shortest distance is 1170.5544127916278 meters
# Shortest distance is 1306.3665109628282 meters
# Shortest distance is 5611.109803635521 meters
# Shortest distance is 6131.281501556844 meters
# Shortest distance is 6751.888955735001 meters
# Shortest distance is 5151.6808649432405 meters
# Shortest distance is 6215.21967853123 meters
# Shortest distance is 367.3710044556468 meters
# Shortest distance is 1032.7596488420322 meters
# Shortest distance is 1523.9527369853026 meters
# Shortest distance is 1497.7848626941084 meters
# Shortest distance is 1463.7015668806555 meters
# Shortest distance is 1461.51725563327 meters
# Shortest distance is 1101.545681846765 meters
# Shortest distance is 5161.0404965519165 meters
# Shortest distance is 5730.06089943028 meters
# Shortest distance is 5827.25875638793 meters
# Shortest distance is 1719.4922193188038 meters
# Shortest distance is 5527.193272785412 meters
# Shortest distance is 1365.5521965079677 meters
# Shortest distance is 1219.4459916491792 meters
# Shortest distance is 1171.587538916755 meters
# Shortest distance is 3264.272705334921 meters
# Shortest distance is 4347.806733575525 meters
# Shortest distance is 632.2236674019266 meters
# Shortest distance is 1878.6264001222826 meters
# Shortest distance is 2020.8329806274842 meters
# Shortest distance is 3057.7587575318307 meters
# Shortest distance is 4351.949787361383 meters
# Shortest distance is 4907.789742079662 meters
# Shortest distance is 4563.156201652274 meters
# Shortest distance is 4105.974610864361 meters
# Shortest distance is 4185.12991897988 meters
# Shortest distance is 4221.0343857351545 meters
# Shortest distance is 3440.76614024846 meters
# Shortest distance is 3475.1514909710268 meters
# Shortest distance is 3332.227891171158 meters
# Shortest distance is 1255.1589781911425 meters
# Shortest distance is 5107.928715601076 meters
# Shortest distance is 1875.7796489014881 meters
# Shortest distance is 1215.0427290347686 meters
# Shortest distance is 9456.67638594705 meters
# Shortest distance is 5047.093234673164 meters
# Shortest distance is 6388.87741516947 meters
# Shortest distance is 4981.385859035223 meters
# Shortest distance is 5169.7217496845715 meters
# Shortest distance is 5042.0928689485445 meters
# Shortest distance is 1036.0173878706942 meters
# Shortest distance is 2004.076245266146 meters
# Shortest distance is 2900.3105664657237 meters
# Shortest distance is 4787.551793072033 meters
# Shortest distance is 4765.164758811949 meters
# Shortest distance is 5671.136300455312 meters
# Shortest distance is 5972.673833407512 meters
# Shortest distance is 899.7642429040536 meters
# Shortest distance is 1206.240529572957 meters
# Shortest distance is 1599.715909258875 meters
# Shortest distance is 1707.3129558986498 meters
# Shortest distance is 318.4612682899215 meters
# Shortest distance is 1410.034148695324 meters
# Shortest distance is 1196.4668831264066 meters
# Shortest distance is 4292.1070634459065 meters
# Shortest distance is 4236.407224609296 meters
# Shortest distance is 1937.4847235158534 meters
# Shortest distance is 2911.422769869146 meters
# Shortest distance is 4855.866380879773 meters
# Shortest distance is 4354.46481070798 meters
# Shortest distance is 4561.068994809129 meters
# Shortest distance is 3074.9181969839465 meters
# Shortest distance is 3007.456694464253 meters
# Shortest distance is 2980.1015501111383 meters
# Shortest distance is 2131.438547113892 meters
# Shortest distance is 291.01961053046296 meters
# Shortest distance is 657.7632054909159 meters
# Shortest distance is 266.62017182910233 meters
# Shortest distance is 1116.0646347336494 meters
# Shortest distance is 1180.3016642559526 meters
# Shortest distance is 9553.680645251115 meters
# Shortest distance is 5124.002621666997 meters
# Shortest distance is 1787.5386320467276 meters
# Shortest distance is 1493.956265531992 meters
# Shortest distance is 1426.5391284254645 meters
# Shortest distance is 5478.1107409827255 meters
# Shortest distance is 4282.318651191995 meters
# Shortest distance is 474.4346976939811 meters
# Shortest distance is 464.97773233892667 meters
# Shortest distance is 461.8908960583425 meters
# Shortest distance is 1283.267124606039 meters
# Shortest distance is 1777.5845105064625 meters
# Shortest distance is 6226.051697316022 meters
# Shortest distance is 7612.576714608266 meters
# Shortest distance is 648.514143625617 meters
# Shortest distance is 1897.866222249009 meters
# Shortest distance is 2227.479466740096 meters
# Shortest distance is 4904.182840988544 meters
# Shortest distance is 4850.715737270182 meters
# Shortest distance is 4867.089483594314 meters
# Shortest distance is 4524.863613819503 meters
# Shortest distance is 4096.807268085663 meters
# Shortest distance is 4268.808813798189 meters
# Shortest distance is 4228.53820814074 meters
# Shortest distance is 2875.05850241074 meters
# Shortest distance is 3015.4771646873355 meters
# Shortest distance is 2934.0495965307473 meters
# Shortest distance is 2406.479708692685 meters
# Shortest distance is 444.2040436099175 meters
# Shortest distance is 1212.8227157278816 meters
# Shortest distance is 5234.217476115135 meters
# Shortest distance is 5895.20869127731 meters
# Shortest distance is 488.7756199889254 meters
# Shortest distance is 966.0419407109056 meters
# Shortest distance is 2006.0530157387775 meters
# Shortest distance is 5745.705645052516 meters
# Shortest distance is 5703.2407840073865 meters
# Shortest distance is 3992.6046795868783 meters
# Shortest distance is 5778.2285337916 meters
# Shortest distance is 4361.194429539125 meters
# Shortest distance is 5965.159699880458 meters
# Shortest distance is 887.5987560608501 meters
# Shortest distance is 1716.0479579901294 meters
# Shortest distance is 1817.5931686489323 meters
# Shortest distance is 2194.291084707821 meters
# Shortest distance is 4876.218473604805 meters
# Shortest distance is 4569.682070272978 meters
# Shortest distance is 4846.065044897203 meters
# Shortest distance is 4496.123966435584 meters
# Shortest distance is 4106.082522727017 meters
# Shortest distance is 2921.197631065601 meters
# Shortest distance is 2897.568322651194 meters
# Shortest distance is 2933.559818781958 meters
# Shortest distance is 3049.6632505458842 meters
# Shortest distance is 2896.098622383597 meters
# Shortest distance is 3554.832950287384 meters
# Shortest distance is 3678.9235419818046 meters
# Shortest distance is 2109.5919416531838 meters
# Shortest distance is 2279.505115300907 meters
# Shortest distance is 4726.887490608821 meters
# Shortest distance is 4996.34547929133 meters
# Shortest distance is 4979.584568370736 meters
# Shortest distance is 1402.6423260630572 meters
# Shortest distance is 569.5630194054492 meters
# Shortest distance is 467.3941541132429 meters
# Shortest distance is 3946.0775428032703 meters
# Shortest distance is 5829.124894462897 meters
# Shortest distance is 5750.0791654926625 meters
# Shortest distance is 5917.061624234807 meters
# Shortest distance is 5850.7748007376185 meters
# Shortest distance is 675.3445021118265 meters
# Shortest distance is 3192.5843619280326 meters
# Shortest distance is 4484.772334514881 meters
# Shortest distance is 4583.986831508612 meters
# Shortest distance is 4602.587613123841 meters
# Shortest distance is 4803.012075809261 meters
# Shortest distance is 4146.690212373257 meters
# Shortest distance is 3818.2334680847143 meters
# Shortest distance is 1543.3728066618175 meters
# Shortest distance is 8795.059970151524 meters
# Shortest distance is 5090.351423210021 meters
# --- 686.7325568199158 seconds ---

# %%
def get_cbd_dist_m(lst_origin):
    cbd_dist = []
    for origin in lst_origin:
        cbd_dist.append(geodesic(origin,(1.2830, 103.8513)).meters)

# %%
cbd_dist = get_cbd_dist_m(hdb_lat_lng)

# %%
# Creating new columns in dataframe
df_enriched['nearest_mrt_dist'] = nearest_mrt_dist
df_enriched['nearest_mall_dist'] = nearest_mall_dist
df_enriched['nearest_govt_aided_dist'] = nearest_govt_aided_dist
df_enriched['nearest_funded_dist'] = nearest_govt_funded_dist
df_enriched['nearest_sap_dist'] = nearest_sap_dist

# %%
# Re-merging dataframes
combined = df_enriched.merge(df_hdb_price, on="address", how="outer")

# %%
combined.shape
# Out:
# (70126, 23)

# %%
combined.dropna(inplace=True)

# %%
combined.drop(['blk_no', 'road_name'], axis=1, inplace=True)

# %%
combined.to_csv("./data_sets/combined_"+datetime.today().strftime("%Y-%m-%d")+".csv", index = False)
